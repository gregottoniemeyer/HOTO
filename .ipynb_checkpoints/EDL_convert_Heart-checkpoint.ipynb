# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file
file_path = './data/creatures_EDL.csv'
df = pd.read_csv(file_path, sep='\t')
df.columns = ['CHANNEL', 'EVENT', 'CLIP NAME', 'START TIME', 'END TIME', 'DURATION', 'STATE']

# %%
df.head()
# Out:
#     CHANNEL     EVENT                           CLIP NAME      START TIME  \
# 0  1         1         P3 Alien Fish Chatter Ab-Mldy-01.L     00:03:12:14
# 1  1         2         P3 Alien Fish Chatter Ab-Mldy-02.L     00:03:17:12
# 2  1         3         P3 Alien Fish Chatter Ab-Mldy-03.L     00:03:26:12
# 3  1         4         P3 Alien Fish Chatter Ab-Mldy-04.L     00:03:28:06
# 4  1         5         P3 Alien Fish Chatter Ab-Mldy-05.L     00:03:37:27
#
#          END TIME        DURATION    STATE
# 0     00:03:13:20     00:00:01:05  Unmuted
# 1     00:03:19:05     00:00:01:23  Unmuted
# 2     00:03:28:06     00:00:01:24  Unmuted
# 3     00:03:31:11     00:00:03:05  Unmuted
# 4     00:03:38:16     00:00:00:19  Unmuted

# %%
df.shape
# Out:
# (59, 7)

# %%
df['DURATION'] = df['DURATION'].str.strip()
df['START TIME'] = df['START TIME'].str.strip()
df['END TIME'] = df['END TIME'].str.strip()

# %%
#clean data
df_cleaned = df[df['DURATION'] != "00:00:00:00"]

# Reindex the DataFrame
df_cleaned.reset_index(drop=True, inplace=True)

# Display the cleaned DataFrame
print(df_cleaned)
# Out:
#      CHANNEL     EVENT                              CLIP NAME   START TIME  \
# 0   1         1            P3 Alien Fish Chatter Ab-Mldy-01.L  00:03:12:14
# 1   1         2            P3 Alien Fish Chatter Ab-Mldy-02.L  00:03:17:12
# 2   1         3            P3 Alien Fish Chatter Ab-Mldy-03.L  00:03:26:12
# 3   1         4            P3 Alien Fish Chatter Ab-Mldy-04.L  00:03:28:06
# 4   1         5            P3 Alien Fish Chatter Ab-Mldy-05.L  00:03:37:27
# 5   1         6            P3 Alien Fish Chatter Ab-Mldy-06.L  00:03:48:29
# 6   1         7            P3 Alien Fish Chatter Ab-Mldy-07.L  00:03:59:14
# 7   1         8                SFX LFO Sparkles Ab-Mldy-02.L   00:06:32:04
# 8   1         9                SFX Water Comb-Mldy-05.L        00:06:52:23
# 9   1         10               SFX Water Comb-Mldy-06.L        00:07:04:00
# 10  1         11               SFX Water Comb-Mldy-07.L        00:07:36:17
# 11  CHANNEL   EVENT            CLIP NAME                        START TIME
# 12  1         1         Rising Crystal Bubbles 3 mins Ab-04.L  00:10:18:11
# 13  CHANNEL   EVENT            CLIP NAME                        START TIME
# 14  1         1                Squid moving in water-09.L      00:05:17:24
# 15  1         2                Squid moving in water-10.L      00:05:25:05
# 16  1         3                Squid moving in water-03.L      00:05:35:27
# 17  1         4                Squid moving in water-05.L      00:05:43:02
# 18  1         5                Squid moving in water-07.L      00:05:53:20
# 19  1         6                Squid moving in water-08.L      00:06:20:22
# 20  1         7                Squid moving in water-03.L      00:06:45:00
# 21  1         9                Squid moving in water-07.L      00:07:10:13
# 22  CHANNEL   EVENT            CLIP NAME                        START TIME
# 23  1         1                SFX Squid-20.L                  00:09:16:27
# 24  1         2                SFX Squid-19.L                  00:09:24:04
# 25  1         3                SFX Squid-21.L                  00:09:34:18
# 26  1         4                SFX Squid-18.L                  00:09:44:10
# 27  CHANNEL   EVENT            CLIP NAME                        START TIME
# 28  1         1                Modular Creature 4-12.L         00:04:19:03
# 29  1         2                Modular Creature 4-13.L         00:04:30:21
# 30  1         3                Modular Creature 4-15.L         00:04:39:12
# 31  1         4                Modular Creature 4-14.L         00:04:41:18
# 32  1         5                Modular Creature 4-11.L         00:04:53:09
# 33  1         6                Modular Creature 4-10.L         00:05:02:17
# 34  1         7             Modular Creature 4-PnTPro_01-01.L  00:05:25:13
# 35  1         8             Modular Creature 4-PnTPro_02-01.L  00:05:30:28
# 36  1         9             Modular Creature 4-PnTPro_03-01.L  00:05:34:10
# 37  1         10            Modular Creature 4-PnTPro_04-01.L  00:05:51:08
# 38  1         11            Modular Creature 4-PnTPro_05-01.L  00:05:58:08
# 39  1         12            Modular Creature 4-PnTPro_06-02.L  00:06:09:23
# 40  1         13            Modular Creature 4-PnTPro_07-01.L  00:06:11:12
# 41  CHANNEL   EVENT            CLIP NAME                        START TIME
# 42  1         1                Clang Inst.02-cm_01-02.L        00:00:50:00
# 43  1         2                Clang Inst.02-cm_01-04.L        00:01:20:29
# 44  1         3                Clang Inst.02-cm_01-06.L        00:01:44:24
# 45  1         4                Clang Inst.02-cm_01-08.L        00:01:55:19
# 46  1         5                Clang Inst.02-cm_01-10.L        00:02:16:09
# 47  1         6                Clang Inst.02-cm_01-12.L        00:02:27:18
# 48  1         7                Clang Inst.02-cm_01-14.L        00:02:50:11
# 49  1         8                Clang Inst.02-cm_01-16.L        00:03:26:08
# 50  1         9                Clang Inst.02-cm_01-18.L        00:04:05:23
# 51  1         10               Clang Inst.02-cm_01-20.L        00:04:28:29
# 52  1         11               Clang Inst.02-cm_01-22.L        00:04:49:29
# 53  1         12               Clang Inst.02-cm_01-24.L        00:05:35:26
# 54  1         13               Clang Inst.02-cm_01-26.L        00:10:31:14
# 55  1         14               Clang Inst.02-cm_01-28.L        00:10:54:00
# 56  1         15               Clang Inst.02-cm_01-30.L        00:11:26:23
# 57  1         16               Clang Inst.02-cm_01-32.L        00:11:37:00
# 58  1         17               Clang Inst.02-cm_01-33.L        00:11:50:15
#
#        END TIME     DURATION    STATE
# 0   00:03:13:20  00:00:01:05  Unmuted
# 1   00:03:19:05  00:00:01:23  Unmuted
# 2   00:03:28:06  00:00:01:24  Unmuted
# 3   00:03:31:11  00:00:03:05  Unmuted
# 4   00:03:38:16  00:00:00:19  Unmuted
# 5   00:03:50:21  00:00:01:21  Unmuted
# 6   00:04:03:13  00:00:03:28  Unmuted
# 7   00:06:36:04  00:00:03:29  Unmuted
# 8   00:06:54:18  00:00:01:25  Unmuted
# 9   00:07:07:12  00:00:03:11  Unmuted
# 10  00:07:39:28  00:00:03:11  Unmuted
# 11     END TIME     DURATION    STATE
# 12  00:10:20:06  00:00:01:24  Unmuted
# 13     END TIME     DURATION    STATE
# 14  00:05:23:01  00:00:05:06  Unmuted
# 15  00:05:29:01  00:00:03:25  Unmuted
# 16  00:05:39:03  00:00:03:05  Unmuted
# 17  00:05:46:08  00:00:03:06  Unmuted
# 18  00:05:57:00  00:00:03:10  Unmuted
# 19  00:06:30:19  00:00:09:27  Unmuted
# 20  00:06:48:06  00:00:03:05  Unmuted
# 21  00:07:13:23  00:00:03:10  Unmuted
# 22     END TIME     DURATION    STATE
# 23  00:09:20:07  00:00:03:10  Unmuted
# 24  00:09:27:20  00:00:03:16  Unmuted
# 25  00:09:38:06  00:00:03:18  Unmuted
# 26  00:09:47:16  00:00:03:06  Unmuted
# 27     END TIME     DURATION    STATE
# 28  00:04:19:13  00:00:00:10  Unmuted
# 29  00:04:31:28  00:00:01:07  Unmuted
# 30  00:04:40:18  00:00:01:06  Unmuted
# 31  00:04:42:26  00:00:01:08  Unmuted
# 32  00:04:53:23  00:00:00:13  Unmuted
# 33  00:05:03:25  00:00:01:08  Unmuted
# 34  00:05:26:06  00:00:00:23  Unmuted
# 35  00:05:31:26  00:00:00:28  Unmuted
# 36  00:05:35:09  00:00:00:28  Unmuted
# 37  00:05:52:09  00:00:01:00  Unmuted
# 38  00:05:59:14  00:00:01:05  Unmuted
# 39  00:06:11:09  00:00:01:16  Unmuted
# 40  00:06:13:07  00:00:01:24  Unmuted
# 41     END TIME     DURATION    STATE
# 42  00:00:53:25  00:00:03:24  Unmuted
# 43  00:01:24:21  00:00:03:22  Unmuted
# 44  00:01:48:16  00:00:03:22  Unmuted
# 45  00:01:59:14  00:00:03:24  Unmuted
# 46  00:02:20:00  00:00:03:21  Unmuted
# 47  00:02:31:12  00:00:03:24  Unmuted
# 48  00:02:53:29  00:00:03:18  Unmuted
# 49  00:03:30:03  00:00:03:24  Unmuted
# 50  00:04:09:12  00:00:03:18  Unmuted
# 51  00:04:32:17  00:00:03:18  Unmuted
# 52  00:04:53:20  00:00:03:20  Unmuted
# 53  00:05:39:15  00:00:03:19  Unmuted
# 54  00:10:35:09  00:00:03:25  Unmuted
# 55  00:10:57:20  00:00:03:20  Unmuted
# 56  00:11:30:12  00:00:03:19  Unmuted
# 57  00:11:40:18  00:00:03:18  Unmuted
# 58  00:11:54:05  00:00:03:20  Unmuted

# %%
df_cleaned.shape
# Out:
# (59, 7)

# %%
df_cleaned.head()
# Out:
#     CHANNEL     EVENT                           CLIP NAME   START TIME  \
# 0  1         1         P3 Alien Fish Chatter Ab-Mldy-01.L  00:03:12:14
# 1  1         2         P3 Alien Fish Chatter Ab-Mldy-02.L  00:03:17:12
# 2  1         3         P3 Alien Fish Chatter Ab-Mldy-03.L  00:03:26:12
# 3  1         4         P3 Alien Fish Chatter Ab-Mldy-04.L  00:03:28:06
# 4  1         5         P3 Alien Fish Chatter Ab-Mldy-05.L  00:03:37:27
#
#       END TIME     DURATION    STATE
# 0  00:03:13:20  00:00:01:05  Unmuted
# 1  00:03:19:05  00:00:01:23  Unmuted
# 2  00:03:28:06  00:00:01:24  Unmuted
# 3  00:03:31:11  00:00:03:05  Unmuted
# 4  00:03:38:16  00:00:00:19  Unmuted

# %%
def timecode_to_frames(timecode):
    try:
        hours, minutes, seconds, frames = map(int, timecode.split(':'))
        total_frames = ((hours * 3600) + (minutes * 60) + seconds) * 30 + frames
        return total_frames
    except ValueError:
        return None  # Return None for invalid timecodes

# Apply the function to the 'START TIME' column
df_cleaned['Frames'] = df_cleaned['START TIME'].apply(timecode_to_frames)
df_cleaned.head()
# Out:
#     CHANNEL     EVENT                           CLIP NAME   START TIME  \
# 0  1         1         P3 Alien Fish Chatter Ab-Mldy-01.L  00:03:12:14
# 1  1         2         P3 Alien Fish Chatter Ab-Mldy-02.L  00:03:17:12
# 2  1         3         P3 Alien Fish Chatter Ab-Mldy-03.L  00:03:26:12
# 3  1         4         P3 Alien Fish Chatter Ab-Mldy-04.L  00:03:28:06
# 4  1         5         P3 Alien Fish Chatter Ab-Mldy-05.L  00:03:37:27
#
#       END TIME     DURATION    STATE  Frames
# 0  00:03:13:20  00:00:01:05  Unmuted  5774.0
# 1  00:03:19:05  00:00:01:23  Unmuted  5922.0
# 2  00:03:28:06  00:00:01:24  Unmuted  6192.0
# 3  00:03:31:11  00:00:03:05  Unmuted  6246.0
# 4  00:03:38:16  00:00:00:19  Unmuted  6537.0

# %%
# Convert 'Frames' to integer
df_cleaned['Frames'] = df_cleaned['Frames'].fillna(0)
df_cleaned['Frames'] = df_cleaned['Frames'].astype(int)

# Sort by 'Frames' column in ascending order and reset the index
df_cleaned = df_cleaned.sort_values(by='Frames').reset_index(drop=True)
df_cleaned.tail()
# Out:
#      CHANNEL     EVENT                       CLIP NAME   START TIME  \
# 54  1         13        Clang Inst.02-cm_01-26.L        00:10:31:14
# 55  1         14        Clang Inst.02-cm_01-28.L        00:10:54:00
# 56  1         15        Clang Inst.02-cm_01-30.L        00:11:26:23
# 57  1         16        Clang Inst.02-cm_01-32.L        00:11:37:00
# 58  1         17        Clang Inst.02-cm_01-33.L        00:11:50:15
#
#        END TIME     DURATION    STATE  Frames
# 54  00:10:35:09  00:00:03:25  Unmuted   18944
# 55  00:10:57:20  00:00:03:20  Unmuted   19620
# 56  00:11:30:12  00:00:03:19  Unmuted   20603
# 57  00:11:40:18  00:00:03:18  Unmuted   20910
# 58  00:11:54:05  00:00:03:20  Unmuted   21315

# %%
# Save the new DataFrame as a CSV file
output_path = './data/creatures_01.csv'
df_cleaned.to_csv(output_path, index=False)
