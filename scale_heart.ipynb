# %%
import pandas as pd

# %%
df = pd.read_csv("../data/energy_values_lights.csv", header=0)

# %%
df.head()
# Out:
#    frame  light_001_energy  light_000_energy
# 0      0          0.000000          0.000000
# 1      1          0.099995          0.050730
# 2      2          0.099979          0.051458
# 3      3          0.099952          0.052183
# 4      4          0.099916          0.052905

# %%
import matplotlib.pyplot as plt

# Plot the scaled data
plt.plot(df.index, df["light_000_energy"], label='Scaled Depth Data')
plt.xlabel('Index')
plt.ylabel('Scaled Value')
plt.title('Scaled Depth Data Plot')
plt.legend()

# Display the plot
plt.show()

# %%
scaled_depth_data.to_csv("../data/scaled_heart_data.csv", index=False)
